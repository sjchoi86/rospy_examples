# %% [markdown]
# ### Screenshot Gazebo Screen

# %%
import os
from IPython.display import Image
print ("Packages loaded.")
# Out:
# Packages loaded.

# %%
imgName = 'gazebo_screen'
os.system("./gazebo_screen.sh %s"%(imgName))
print ("pics/%s.png saved."%(imgName))
# Out:
# pics/gazebo_screen.png saved.

# %%
"""
<img src="pics/gazebo_screen.png" height="200" width="600">
"""
# Out:
# '\n<img src="pics/gazebo_screen.png" height="200" width="600">\n'

# %%
Image("pics/gazebo_screen.png",width=600,height=300)
